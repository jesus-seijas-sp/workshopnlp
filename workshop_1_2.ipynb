# %%
# !pip install transformers
# !pip install sentencepiece

# %%
from transformers import pipeline
import textwrap
import pprint

# %%
visual_qa = pipeline("visual-question-answering")
from IPython.display import Image
Image('./data/perretes.jpg')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision 4355f59 (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
visual_qa(image="./data/perretes.jpg", question="What animal is in this picture?", top_k=3)
# Out:
# [{'score': 0.9809065461158752, 'answer': 'dog'},
#  {'score': 0.36590948700904846, 'answer': 'dogs'},
#  {'score': 0.02640727162361145, 'answer': 'dog and cat'}]

# %%
visual_qa(image="./data/perretes.jpg", question="How many dogs are there?", top_k=3)
# Out:
# [{'score': 0.621559202671051, 'answer': '3'},
#  {'score': 0.5141502022743225, 'answer': '2'},
#  {'score': 0.06546350568532944, 'answer': '4'}]

# %%
visual_qa(image="./data/perretes.jpg", question="What's the color of the couch?", top_k=3)
# Out:
# [{'score': 0.9957470297813416, 'answer': 'blue'},
#  {'score': 0.02042413130402565, 'answer': 'gray'},
#  {'score': 0.01111628208309412, 'answer': 'purple'}]

# %%
visual_qa(image="./data/perretes.jpg", question="What's the color of the dog at the left?", top_k=3)
# Out:
# [{'score': 0.6906576752662659, 'answer': 'white'},
#  {'score': 0.3193309009075165, 'answer': 'brown'},
#  {'score': 0.16650575399398804, 'answer': 'white and brown'}]

# %%
visual_qa(image="./data/perretes.jpg", question="What's the color of the wall?", top_k=3)
# Out:
# [{'score': 0.9128206372261047, 'answer': 'brown'},
#  {'score': 0.5218706727027893, 'answer': 'tan'},
#  {'score': 0.12970930337905884, 'answer': 'beige'}]
