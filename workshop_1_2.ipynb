# %%
# !pip install transformers
# !pip install sentencepiece

# %%
from transformers import pipeline
import textwrap
import pprint

# %%
visual_qa = pipeline("visual-question-answering")
from IPython.display import Image
Image('./data/dogs.jpg')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision 4355f59 (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
visual_qa(image="./data/dogs.jpg", question="What animal is in this picture?", top_k=3)
# Out:
# [{'score': 0.8367376327514648, 'answer': 'dog'},
#  {'score': 0.05314014106988907, 'answer': 'dogs'},
#  {'score': 0.03191667050123215, 'answer': 'puppy'}]

# %%
visual_qa(image="./data/dogs.jpg", question="How many dogs are there?", top_k=3)
# Out:
# [{'score': 0.9694176912307739, 'answer': '2'},
#  {'score': 0.016762007027864456, 'answer': '1'},
#  {'score': 0.0008604807080700994, 'answer': '3'}]
